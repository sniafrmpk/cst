# %%
# %run visualizing_LMCs_multiprocessing_R_sparse_direct.py
# Out:
# Generating the final coordinates took: 0.14 s
# R^1 found and it took  1.00 s
# Finding tau_c took:  40.61 s
# There are 1 maximal chains of length 0 between element 0 and 79999
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Desktop/GitRepos/cst_longest_maximal_chains/Saving Rd multiprocessing - R_sparse direct/visualizing_LMCs_multiprocessing_R_sparse_direct.py:537
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/Desktop/GitRepos/cst_longest_maximal_chains/Saving Rd multiprocessing - R_sparse direct/visualizing_LMCs_multiprocessing_R_sparse_direct.py:427, in visualizing_LMCs(N)
#     425 R = R_from_fc_sparse(fc)
#     426 k_max = causet_tau_c_files(folder_path, R, i, j)
# --> 427 L = L_from_R_files(folder_path)
#     428 all_levels = LMCs_v32_files(folder_path, L, k_max, i ,j)
#     430 tf = time.time()
#
# ...
